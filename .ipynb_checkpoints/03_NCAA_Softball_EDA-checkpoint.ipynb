# %% [markdown]
# ## [NYCDSA Capstone Project]
# # Women's Softball League Power Ranking Estimate
#
# <br>
# Koeun Lim (koeunlim@alum.mit.edu)<br>
# Kevin Haghi (kevin.haghi@gmail.com)<br>
#
#
# # Step 3. Exploratory Data Analysis
#
# ---
# ## Project Description
#
#
#
# ### Project Outline
# - Step 1. Web scraping
# - Step 2. Clean data
# - Step 3. EDA
# - Step 4. Imputation & PCA
# - Step 5. Modeling (1) RPI prediction based on stats

# %%
import os, sys
import pandas as pd
import numpy as np
import seaborn as sns

import plotly.graph_objects as go
from matplotlib import pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 5)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 250)

# %%
# %store -r df_ext

# %%
print(df_ext.shape)
df_ext.head()
# Out:
# (2080, 27)
#    RPI_Ranking        College Conference   Record    Road Neutral    Home  \
# 0          1.0       Oklahoma     Big 12   57-6-0  20-0-0  19-5-0  18-1-0
# 1          2.0           UCLA     Pac-12   56-6-0  14-1-0  19-1-0  23-4-0
# 2          3.0     Washington     Pac-12   52-9-0  16-1-0  18-5-0  18-3-0
# 3          4.0        Arizona     Pac-12  48-14-0  16-2-0   6-5-0  26-7-0
# 4          5.0  Florida State        ACC  55-10-0  14-6-0   9-0-0  32-4-0
#
#   Non-Div-I  Year  Fielding_Percentage  Scoring  WL_Percentage  Hit_Batters  \
# 0     0-0-0  2019                0.984     7.30          0.905         14.0
# 1     0-0-0  2019                0.974     7.03          0.903         42.0
# 2     0-0-0  2019                0.980     5.25          0.852         24.0
# 3     0-0-0  2019                0.976     6.48          0.774         22.0
# 4     0-0-0  2019                0.973     6.98          0.846         32.0
#
#    Earned_Run_Average  Triples_per_Game  Home_Runs_per_game  \
# 0                1.40              0.30                1.83
# 1                1.43              0.21                1.26
# 2                1.47              0.15                0.79
# 3                1.61              0.11                1.77
# 4                1.87              0.28                1.62
#
#    Slugging_Percentage  Double_Plays_per_Game  On_Base_Percentage  \
# 0                0.639                   0.25               0.435
# 1                0.547                   0.23               0.416
# 2                0.440                   0.21               0.383
# 3                0.570                   0.29               0.398
# 4                0.601                   0.37               0.421
#
#    Stolen_Bases_per_Game  Strikeout-to-Walk_Ratio  Batting_Average  \
# 0                   0.97                     6.50            0.344
# 1                   0.98                     5.52            0.339
# 2                   0.80                     5.79            0.297
# 3                   0.23                     3.71            0.318
# 4                   1.77                     3.74            0.330
#
#    Doubles_per_Game  Shutouts  Team_Strikeouts_Per_Seven_Innings  WCWS_Rank  \
# 0              1.60      28.0                                NaN        2.0
# 1              1.45      20.0                                NaN        1.0
# 2              1.20      24.0                                NaN        3.0
# 3              1.18      15.0                                NaN        5.0
# 4              1.58      22.0                                NaN        9.0
#
#    WCWS_in
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# #### Pairplot

# %%
pair_stats = sns.pairplot(data=df_ext,diag_kind='kde',
                         plot_kws=dict(alpha=0.2,edgecolor=[]), diag_kws=dict(shade=False), corner=True)

# %%
corrMatrix = df_ext.corr()
sns.heatmap(corrMatrix, annot=False, cmap="Spectral")
plt.show()

# %%
RPI_corr = pd.DataFrame(corrMatrix.sort_values('RPI_Ranking',ascending=False).RPI_Ranking)
RPI_corr = RPI_corr[abs(RPI_corr)<1]
RPI_corr[abs(RPI_corr)>0.5].dropna()
# Out:
#                          RPI_Ranking
# WCWS_Rank                   0.728619
# Earned_Run_Average          0.680222
# Batting_Average            -0.545006
# Home_Runs_per_game         -0.553945
# Strikeout-to-Walk_Ratio    -0.555075
# WCWS_in                    -0.590451
# Slugging_Percentage        -0.618056
# Scoring                    -0.618399
# Fielding_Percentage        -0.637843
# Shutouts                   -0.712039
# On_Base_Percentage         -0.738216
# WL_Percentage              -0.845335

# %%
corr_sorted = pd.DataFrame(corrMatrix.unstack().sort_values(kind="quicksort",ascending=False).drop_duplicates())
corr_sorted.columns = ['rho']
corr_sorted = corr_sorted[abs(corr_sorted)<1]
corr_sorted[abs(corr_sorted)>0.6].dropna()
# Out:
#                                                   rho
# On_Base_Percentage      Scoring              0.954298
#                         Batting_Average      0.924886
# Scoring                 Slugging_Percentage  0.918692
# Slugging_Percentage     On_Base_Percentage   0.908240
# Home_Runs_per_game      Slugging_Percentage  0.887002
# Scoring                 Batting_Average      0.883484
# Slugging_Percentage     Batting_Average      0.865616
# WL_Percentage           On_Base_Percentage   0.810078
#                         Shutouts             0.799732
#                         Scoring              0.750408
# On_Base_Percentage      Home_Runs_per_game   0.741296
# Strikeout-to-Walk_Ratio Shutouts             0.737138
# Scoring                 Home_Runs_per_game   0.732356
# RPI_Ranking             WCWS_Rank            0.730059
# WL_Percentage           Slugging_Percentage  0.701424
#                         Batting_Average      0.683056
# Earned_Run_Average      RPI_Ranking          0.680490
# Slugging_Percentage     Doubles_per_Game     0.678533
# Strikeout-to-Walk_Ratio WL_Percentage        0.669239
# Fielding_Percentage     WL_Percentage        0.651183
# Batting_Average         Doubles_per_Game     0.619858
# Doubles_per_Game        Scoring              0.616650
# WL_Percentage           WCWS_Rank           -0.617145
# Scoring                 RPI_Ranking         -0.618279
# Slugging_Percentage     RPI_Ranking         -0.618551
# Fielding_Percentage     Earned_Run_Average  -0.619285
# RPI_Ranking             Fielding_Percentage -0.638005
# On_Base_Percentage      Year                -0.701301
# Strikeout-to-Walk_Ratio Earned_Run_Average  -0.709243
# Shutouts                RPI_Ranking         -0.712039
# On_Base_Percentage      RPI_Ranking         -0.738216
# Earned_Run_Average      Shutouts            -0.753302
# WL_Percentage           Earned_Run_Average  -0.811911
# RPI_Ranking             WL_Percentage       -0.845439

# %%
df_ext[(df_ext.RPI_Ranking < 10) & (df_ext.WCWS_in == 0)][['College','Year','WL_Percentage','RPI_Ranking','WCWS_Rank']]
# Out:
# Empty DataFrame
# Columns: [College, Year, WL_Percentage, RPI_Ranking, WCWS_Rank]
# Index: []

# %%
df_ext.sort_values(by=['WL_Percentage'],ascending = True)[['College','Year','WL_Percentage','RPI_Ranking','WCWS_Rank']].dropna().head(100)
# Out:
#                  College  Year  WL_Percentage  RPI_Ranking  WCWS_Rank
# 1708         Utah Valley  2014          0.300        228.0       49.0
# 1426         Florida A&M  2015          0.316        243.0       49.0
# 1805             Arizona  2013          0.559         31.0       33.0
# 917                Texas  2017          0.559         30.0       17.0
# 628       North Carolina  2016          0.561         36.0       33.0
# 461              Harvard  2018          0.561        165.0       49.0
# 331             Ole Miss  2018          0.561         35.0       17.0
# 107          Weber State  2019          0.563        108.0       33.0
# 922             Arkansas  2017          0.564         35.0       49.0
# 1953          Valparaiso  2013          0.565        178.0       33.0
# 1563                SIUE  2014          0.566         84.0       49.0
# 1964             Hampton  2013          0.567        189.0       49.0
# 154              Harvard  2019          0.568        155.0       49.0
# 1881                 BYU  2013          0.569        106.0       49.0
# 40              Illinois  2019          0.569         41.0       33.0
# 729                Maine  2016          0.571        137.0       49.0
# 910           California  2017          0.571         23.0       17.0
# 1948     Army West Point  2013          0.574        173.0       49.0
# 1258          Ball State  2015          0.576         75.0       33.0
# 345                Tulsa  2018          0.576         49.0       33.0
# 909       South Carolina  2017          0.576         22.0       17.0
# 1255            Longwood  2015          0.576         72.0       33.0
# 1811      South Carolina  2013          0.576         37.0       17.0
# 1612  Northwestern State  2014          0.577        133.0       49.0
# 97        Southern Miss.  2019          0.577         98.0       33.0
# 627           California  2016          0.578         35.0       17.0
# 1812   Mississippi State  2013          0.579         38.0       33.0
# 1435      Texas Southern  2015          0.581        252.0       49.0
# 1278           Dartmouth  2015          0.581         95.0       49.0
# 329        Wichita State  2018          0.582         33.0       17.0
# 25              Missouri  2019          0.583         26.0       17.0
# 1900         Stony Brook  2013          0.583        125.0       49.0
# 367   Jacksonville State  2018          0.583         71.0       17.0
# 338        CSU Fullerton  2018          0.583         42.0       17.0
# 913        Arizona State  2017          0.585         26.0       33.0
# 1814        Oregon State  2013          0.586         40.0       33.0
# 1525             Houston  2014          0.589         47.0       33.0
# 385              Fordham  2018          0.589         89.0       49.0
# 1583              Bryant  2014          0.593        104.0       49.0
# 1011             Montana  2017          0.593        124.0       49.0

# %%
# %store -r df_NCAA
df_NCAA.head()
# Out:
#               College  Year  Fielding_Percentage  Scoring  WL_Percentage  \
# 0  A&M-Corpus Christi  2013                0.949     2.68          0.220
# 1  A&M-Corpus Christi  2014                0.949     3.27          0.150
# 2  A&M-Corpus Christi  2015                0.958     3.47          0.418
# 3  A&M-Corpus Christi  2016                0.961     2.23          0.375
# 4  A&M-Corpus Christi  2017                0.951     2.02          0.250
#
#    Hit_Batters  Earned_Run_Average  Triples_per_Game  Home_Runs_per_game  \
# 0          NaN                5.00              0.10                0.32
# 1          NaN                5.68              0.15                0.48
# 2          NaN                3.44              0.12                0.47
# 3          NaN                3.45              0.02                0.17
# 4          NaN                3.86              0.04                0.19
#
#    Slugging_Percentage  Double_Plays_per_Game  On_Base_Percentage  \
# 0                0.306                   0.28                 NaN
# 1                  NaN                   0.29                 NaN
# 2                0.364                   0.29                 NaN
# 3                0.276                   0.19                 NaN
# 4                0.256                   0.27                 NaN
#
#    Stolen_Bases_per_Game  Strikeout-to-Walk_Ratio  Batting_Average  \
# 0                   0.42                      NaN            0.231
# 1                   0.73                      NaN            0.265
# 2                   0.80                      NaN            0.267
# 3                   0.48                      NaN            0.228
# 4                   0.65                      NaN            0.215
#
#    Doubles_per_Game  Shutouts  Team_Strikeouts_Per_Seven_Innings
# 0              0.80       NaN                                NaN
# 1              1.10       NaN                                NaN
# 2              1.00       NaN                                NaN
# 3              0.65       NaN                                NaN
# 4              0.40       NaN                                NaN

# %%
df_ext[df_ext.College == 'Auburn']
# Out:
#       RPI_Ranking College Conference   Record    Road  Neutral    Home  \
# 19           20.0  Auburn        SEC  39-21-0  6-10-0    9-4-0  24-7-0
# 316          20.0  Auburn        SEC  41-17-0  8-10-0    4-4-0  29-3-0
# 595           3.0  Auburn        SEC  58-12-0  12-3-0   11-3-0  35-6-0
# 894           7.0  Auburn        SEC  49-12-0  10-4-0    8-2-0  31-6-0
# 1186          3.0  Auburn        SEC  56-11-0  12-5-0   14-3-0  30-3-0
# 1496         18.0  Auburn        SEC  42-19-1   7-9-1    7-3-0  28-7-0
# 1840         66.0  Auburn        SEC    30-23     7-9  1- 2- 0   22-12
#
#      Non-Div-I  Year  Fielding_Percentage  Scoring  WL_Percentage  \
# 19       0-0-0  2019                0.968     5.53          0.650
# 316      0-0-0  2018                0.977     5.09          0.707
# 595      0-0-0  2016                0.969     7.94          0.829
# 894      0-0-0  2017                0.970     5.48          0.803
# 1186     0-0-0  2015                0.975     7.85          0.836
# 1496     0-0-0  2014                0.979     7.10          0.685
# 1840       0-0  2013                0.959     5.15          0.566
#
#       Hit_Batters  Earned_Run_Average  Triples_per_Game  Home_Runs_per_game  \
# 19           13.0                2.67              0.20                1.10
# 316          10.0                1.37              0.21                0.74
# 595           NaN                2.19              0.19                1.27
# 894           NaN                1.74              0.23                0.84
# 1186          NaN                3.59              0.16                1.48
# 1496          NaN                3.26              0.02                1.34
# 1840          NaN                3.46              0.17                0.60
#
#       Slugging_Percentage  Double_Plays_per_Game  On_Base_Percentage  \
# 19                  0.476                   0.50               0.369
# 316                 0.426                   0.43                 NaN
# 595                 0.525                   0.57               0.436
# 894                 0.439                   0.77               0.399
# 1186                0.571                   0.63               0.460
# 1496                0.518                   0.61               0.422
# 1840                0.407                   0.19                 NaN
#
#       Stolen_Bases_per_Game  Strikeout-to-Walk_Ratio  Batting_Average  \
# 19                     1.15                     2.42            0.286
# 316                    1.71                      NaN            0.281
# 595                    0.50                      NaN            0.317
# 894                    0.44                      NaN            0.277
# 1186                   0.39                      NaN            0.339
# 1496                   0.27                      NaN            0.305
# 1840                   1.40                      NaN            0.279
#
#       Doubles_per_Game  Shutouts  Team_Strikeouts_Per_Seven_Innings  \
# 19                1.22      13.0                                NaN
# 316               1.07       NaN                                NaN
# 595               1.41       NaN                                NaN
# 894               1.23       NaN                                NaN
# 1186              1.45       NaN                                NaN
# 1496              1.40       NaN                                NaN
# 1840              1.11       NaN                                NaN
#
#       WCWS_Rank  WCWS_in
# 19         17.0        1
# 316        33.0        1
# 595         2.0        1
# 894         9.0        1
# 1186        3.0        1
# 1496       17.0        1
# 1840        NaN        0
