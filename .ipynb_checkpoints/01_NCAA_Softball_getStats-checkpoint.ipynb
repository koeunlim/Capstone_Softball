# %% [markdown]
# ## [NYCDSA Capstone Project]
# # Women's Softball League Power Ranking Estimate
#
# <br>
# Koeun Lim (ke.lim.kang@gmail.com)<br>
# Kevin Haghi (kevin.haghi@gmail.com)<br>
#
#
# # Step 1. Web scraping
#
# ---
# ## Project Description
#
#
#
# ### Project Outline
# - Step 1. Web scraping
# - Step 2. EDA
# - Step 3. Modeling
# - Step 4.

# %%
import pandas as pd
import re
import time

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select

# %%
driver = webdriver.Chrome("/usr/local/bin/chromedriver")

# load the first page
url = 'http://stats.ncaa.org/rankings/'
driver.get(url)
time.sleep(1)

select_sport = Select(driver.find_element_by_id('sport'))
select_sport.select_by_visible_text('Softball')

# %%
select_season = Select(driver.find_element_by_id('acadyr'))
Seasons = ['2018-19','2017-18','2016-17','2015-16','2014-15','2013-14','2012-13']

# Add loop here later
select_season.select_by_visible_text(Seasons[0])

# %%
select_div = Select(driver.find_element_by_id('u_div'))
select_div.select_by_visible_text('I')

# %%
select_period = Select(driver.find_element_by_id('rp'))

period_box = driver.find_element_by_name('rp')
period_options = [x for x in period_box.find_elements_by_tag_name('option')]
for period_option in period_options:
    period_text = period_option.text
    if 'Final Statistics' in period_text:
        select_period.select_by_visible_text(period_text)

# %%
stats_box = driver.find_element_by_name('Stats')
stats_options = [x for x in stats_box.find_elements_by_tag_name('option')]
Stats_names = []
for idx_stats, stats_option in enumerate(stats_options):
    Stats_names.append(stats_option.text)

del Stats_names[0]

select_stats.select_by_visible_text(Stats_names[0])

# %%
select_stats = Select(driver.find_element_by_id('stat_seq'))

# add loop here later
select_stats.select_by_visible_text(Stats_names[1])

# %%
select_len = Select(driver.find_element_by_name('rankings_table_length'))
select_len.select_by_value('-1')

len_str = driver.find_element_by_id('rankings_table_info').text
num_obs = max([int(s) for s in len_str.split() if s.isdigit()])

# %%
# Scrape
soup_level1=BeautifulSoup(driver.page_source, 'lxml')
print(soup_level1.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    NCAA Statistics
#   </title>
#   <link href="/assets/application-31e4d2448e9434c0c2d76b81b5f75954.css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="/assets/pdfmake.min-4bed2d37a29e856f08cf25124b5e5d69.js" type="text/javascript">
#   </script>
#   <script src="/assets/application-6484cb0797671a8bf833045bbeeef071.js" type="text/javascript">
#   </script>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="a3tYSlkLx/1naum2iE6r1AEbslYFbTdQ/XlNeflR1Ow=" name="csrf-token"/>
#   <style>
#    tfoot tr:nth-child(n+2){
#   border: initial;
#   font-weight: initial;
# }
#
# tfoot tr:nth-child(n+2) td{
#   border: initial;
#   font-weight: initial;
# }
#   </style>
#   <script>
#    $.ajaxSetup ({
#     // Disable caching of AJAX responses
#     cache: false
#   });
#
#   function changeSport(field){
#     var el = $(field);
#     var tmList = el.parent().next().find('.new-team-year')[0];
#     if (tmList == null){
#       tmList = el.nextAll('.new-team-year')[0];
#     }
#     $.ajax({
#       url: "/game_sport_year_ctls/"+el.val()+"/available_teams",
#       dataType: "script",
#       success: function(data, status){
#         $(tmList).empty();
#         $(tmList).append(("<option value=''>Select team</option>"));
#         $.each(JSON.parse(data), function(k, v){
#           $(tmList).append($("<option></option>")
#               .attr("value", v["id"])
#               .text(v["member_org"]["name_tabular"]));
#         });
#         $(tmList).trigger("chosen:updated");
#       }
#     });
#   }
#
#     function set_process_styles(fld, start_color, end_color){
#        $('#'+fld).effect('highlight', {color: '#99CC99'}, 6000);
#     }
#
#     var downImage = "/assets/down12.gif";
#     var rightImage = "/assets/right12.gif";
#
#     function highlight(div_id){
#       $(div_id).effect('highlight', {color: '#99CC99'}, 6000);
#     }
#
#     function show_hide_rows(attr_val, link_id){
#       $('#'+attr_val).toggle();
#       if ($('#'+attr_val).is(':visible')) {
#         $('#'+link_id).attr('src', downImage);
#       }else{
#         $('#'+link_id).attr('src', rightImage);
#       }
#     }
#
#     function mask(label){
#       $('body').mask(label);
#     }
#     function unmask(){
#       $('body').unmask();
#     }
#
#     var winHeight = "auto";
#     var winWidth = "auto";
#     var maxHeight = 700;
#     var maxWidth = 1400;
#     var minHeight = 100;
#     var minWidth = 200;
#
#     var modalOptions = {"width": winWidth,
#                         "height": winHeight,
#                         "maxHeight": maxHeight,
#                         "maxWidth": maxWidth,
#                         "minHeight": minHeight,
#                         "minWidth": minWidth};
#
#     function dialog(url, title){
#
#       $("#stats_app_dialog").dialog({modal:true, minWidth:minWidth, minHeight:minHeight, maxWidth:maxWidth, maxHeight:maxHeight, width:winWidth, height:winHeight, title:title, closeOnEscape: false});
#
#       modalOptions.title = title;
#
#       $("#stats_app_dialog").dialog("option", modalOptions);
#
#       $("#stats_app_dialog").html("Loading...");
#       $("#stats_app_dialog").load(url).dialog('open');
#     }
#
#     function addDatePicker(){
#     $('.adddatepicker').each(function(i, obj){
#       $(obj).datepicker({
#         showOn: 'both',
#         buttonImage: '/assets/calendar.gif',
#         buttonImageOnly: true,
#       });
#     });
#     }
#
#    $(document).ready(function() {
#      addDatePicker();
#      $('.chosen-select').chosen({allow_single_deselect: true, search_contains: true, width: '250px'});
#      $('.chosen-select-wide').chosen({allow_single_deselect: true, search_contains: true, width: '400px'});
#    });
#
#    function setClassInputFields(){
#      addDatePicker();
#      $('.chosen-select').chosen({allow_single_deselect: true, search_contains: true, width: '250px'});
#      $('.chosen-select-wide').chosen({allow_single_deselect: true, search_contains: true, width: '400px'});
#    }
#   </script>
#  </head>
#  <body class="" id="body" onload="if (top != self) { top.location=self.location; }">
#   <div id="header">
#    <img alt="Titlebar_logo" height="81" src="/assets/titlebar_logo-d1d40bd2268e265b6a42cacb7bb117e9.jpg" style="float: left" width="104"/>
#    <h1>
#     <span id="title1">
#      NCAA
#     </span>
#     <br/>
#     <span id="title2">
#      Statistics
#     </span>
#    </h1>
#    <div id="nav">
#     <ul>
#      <li id="active">
#       <a href="/rankings?academic_year=2019&amp;division=1.0&amp;sport_code=WSB">
#        <span>
#         National Rankings
#        </span>
#       </a>
#      </li>
#      <li id="notactive">
#       <a href="/active_career_leaders/show_summary_from_rankings?academic_year=2019&amp;division=1.0&amp;sport_code=WSB">
#        <span>
#         Active Career Leaders
#        </span>
#       </a>
#      </li>
#      <li id="notactive">
#       <a href="/contests/scoreboards">
#        <span>
#         Scoreboard
#        </span>
#       </a>
#      </li>
#      <li id="notactive">
#       <a href="/selection_rankings/nitty_gritties">
#        <span>
#         RPI/NET Rankings
#        </span>
#       </a>
#      </li>
#      <li id="notactive">
#       <a href="/head_coaches">
#        <span>
#         Head Coaches
#        </span>
#       </a>
#      </li>
#      <li id="notactive">
#       <a href="/search/players">
#        <span>
#         Player Search
#        </span>
#       </a>
#      </li>
#      <li id="team_search">
#       <script>
#        $(function() {
#     $( "#org_name" ).autocomplete({
#       source: '/team/search',
#       select: function( event, ui ) {
#         $("#org_id").val(ui.item.vid);
#         $("#id").val(ui.item.vid);
#         $('#sport_btn').click();
#       }
#     });
#   });
#       </script>
#       <span style="display:inline; float:right;">
#        <form accept-charset="UTF-8" action="/team/index" id="change_team_form" method="post" onsubmit="mask('Loading');" style="display:inline;">
#         <div style="margin:0;padding:0;display:inline">
#          <input name="utf8" type="hidden" value="✓"/>
#          <input name="authenticity_token" type="hidden" value="a3tYSlkLx/1naum2iE6r1AEbslYFbTdQ/XlNeflR1Ow="/>
#         </div>
#         <div style="display:none;">
#          <input id="sport_btn" name="commit" type="submit" value="Submit"/>
#         </div>
#         <div class="ui-widget" id="team_autocomplete">
#          <span style="color: #ccc;">
#           Team Search:
#          </span>
#          <input autocomplete="off" class="ui-autocomplete-input" id="org_name" name="org_name" style="width:200px" type="text"/>
#          <span aria-live="polite" class="ui-helper-hidden-accessible" role="status">
#          </span>
#          <input id="org_id" name="org_id" type="hidden"/>
#         </div>
#        </form>
#       </span>
#      </li>
#      <li>
#       <a class="skipMask" href="http://twitter.com/ncaastats" target="TWITTER">
#        <img alt="Twitter" height="17" src="/assets/twitter-6586be4273539dff7a95e70ebdf1a846.png" width="46"/>
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <div id="contentarea">
#    <div id="stats_app_dialog" style="display:none;">
#    </div>
#    <div class="rankings" id="message_box" style="display: none">
#     <span class="message_box_success">
#     </span>
#     <span class="message_box_error">
#     </span>
#    </div>
#    <script language="javascript">
#     //used in ranking_summary.rhtml
#    function load_ranking_summary(org_id, conf_id, region_id, ncaa_custom_id, user_custom_id){
#       $('#ranking_summary_form_org_id').val(org_id);
#       $('#ranking_summary_form_conf_id').val(conf_id);
#       $('#ranking_summary_form_region_id').val(region_id);
#       $('#ranking_summary_form_ncaa_custom_rank_summary_id').val(ncaa_custom_id);
#       $('#ranking_summary_form_user_custom_rank_summary_id').val(user_custom_id);
#       $('#ranking_summary_form_submit_btn').click();
#   }
#
#   //used in ranking_summary.rhtml
#   function showCareer(org_id, player_id){
#       $('#career_form_org_id').val(org_id);
#       $('#career_form_player_id').val(player_id);
#       $('#career_form_id').submit();
#    }
#
#    function showLegacyPDF(ranking_period, stat_seq, division, sport_code, academic_year){
#      window.open("http://web1.ncaa.org/stats/StatsSrv/pdf/rankings?rptWeeks="+ranking_period+"&statSeq="+stat_seq+"&div="+division+"&sportCode="+sport_code+"&academicYear="+academic_year+"&rptType=PDF&doWhat=showrankings", "PDF_RANKINGS_"+stat_seq);
#
#    }
#
#       function init_tabs(activate_tab){
#         $("#stat_type_I_N").removeClass("current");
#         $("#stat_type_I_Y").removeClass("current");
#         $("#stat_type_T_N").removeClass("current");
#         $("#stat_type_T_Y").removeClass("current");
#         $("#ranking_summary").removeClass("current");
#         $("#misc_reports").removeClass("current");
#         if(activate_tab != null){
#            $(activate_tab).addClass("current");
#         }
#       }
#
#       function changeRankingSummaryTab(){
#          submitSportYearDivForm("ranking_summary");
#       }
#
#       function changeStatType(tm_ind, gm_high){
# 	     $('#sport_year_div_game_high').val(gm_high);
# 	     $('#sport_year_div_team_individual').val(tm_ind);
# 	     $('#sport_year_div_stat_seq').val('');
# 	     $('#sport_year_div_ranking_summary').val('N');
#          initRankingSummaryOptions();
#          submitSportYearDivForm("change_sport_year_div");
#       }
#
#       function initRankingSummaryOptions(){
#          $('#sport_year_div_org_id').val("-1");
#          $('#sport_year_div_conf_id').val("-1");
#          $('#sport_year_div_region_id').val("-1");
#          $('#sport_year_div_ncaa_custom_rank_summary_id').val("-1");
#          $('#sport_year_div_user_custom_rank_summary_id').val("-1");
#       }
#
#       //this gets called after ajax calls to rankings or ranking summary
#       function initRankingsCall(stat_seq, org, conf, region, ncaa_custom, user_custom){
# 	     $('#sport_year_div_stat_seq').val(stat_seq);
#          $('#sport_year_div_org_id').val(org);
#          $('#sport_year_div_conf_id').val(conf);
#          $('#sport_year_div_region_id').val(region);
#          $('#sport_year_div_ncaa_custom_rank_summary_id').val(ncaa_custom);
#          $('#sport_year_div_user_custom_rank_summary_id').val(user_custom);
#          if ( stat_seq > 0 ){
#             $('#sport_year_div_ranking_summary').val("N");
#          }else{
#             $('#sport_year_div_ranking_summary').val("Y");
#          }
#       }
#
#       function showRankings(stat){
# 	     $('#ranking_form_stat_seq').val(stat);
# 	     document.ranking_form.submit();
#       }
#
#       function changeDivisions(val){
#              $('#sport_year_div_division').val(val);
#              $('#sport_year_div_ranking_period').val('');
#              initRankingSummaryOptions();
#              submitSportYearDivForm("change_sport_year_div");
#       }
#
#       function changeYears(val){
#              $('#sport_year_div_academic_year').val(val);
#              $('#sport_year_div_ranking_period').val('');
#              initRankingSummaryOptions();
#              submitSportYearDivForm("change_sport_year_div");
#       }
#
#       function changeSports(val){
#              $('#sport_year_div_sport_code').val(val);
#              $('#sport_year_div_ranking_period').val('');
#              initRankingSummaryOptions();
#              submitSportYearDivForm("change_sport_year_div");
#       }
#
#       function changeRankingPeriod(val){
# 	     $('#sport_year_div_ranking_period').val(val);
#          submitSportYearDivForm("change_sport_year_div");
#       }
#
#       function submitSportYearDivForm(action_name){
#         $('#contentArea').mask('Loading...');
#         if ($('#sport_year_div_ranking_summary').val() == "Y" && action_name == "change_sport_year_div"){
#            document.sport_year_div_form.action = "/rankings/ranking_summary";
#         }else{
#            document.sport_year_div_form.action = "/rankings/"+action_name;
#         }
#         document.sport_year_div_form.submit();
#       }
#
#       function playerTeamSummary(val){
# 	     $('#player_search_id').val(val);
#    	     document.player_form.submit();
#       }
#
#       function viewRankings(stat_seq){
#         $('#rankings_stat_seq').val(stat_seq);
#         $('#rankings_form_submit_btn').click();
#       }
#    </script>
#    <select id="sport" name="sport" onchange="mask('Processing'); changeSports(this.value);">
#     <option value="">
#      Select Sport
#     </option>
#     <option value="MBA">
#      Baseball
#     </option>
#     <option value="MBB">
#      Men's Basketball
#     </option>
#     <option value="MFB">
#      Football
#     </option>
#     <option value="MIH">
#      Men's Ice Hockey
#     </option>
#     <option value="MLA">
#      Men's Lacrosse
#     </option>
#     <option value="MSO">
#      Men's Soccer
#     </option>
#     <option value="MTE">
#      Men's Tennis
#     </option>
#     <option value="MVB">
#      Men's Volleyball
#     </option>
#     <option value="MWP">
#      Men's Water Polo
#     </option>
#     <option value="WBB">
#      Women's Basketball
#     </option>
#     <option value="WBW">
#      Women's Bowling
#     </option>
#     <option value="WFH">
#      Field Hockey
#     </option>
#     <option value="WIH">
#      Women's Ice Hockey
#     </option>
#     <option value="WLA">
#      Women's Lacrosse
#     </option>
#     <option selected="" value="WSB">
#      Softball
#     </option>
#     <option value="WSO">
#      Women's Soccer
#     </option>
#     <option value="WSV">
#      Women's Beach Volleyball
#     </option>
#     <option value="WTE">
#      Women's Tennis
#     </option>
#     <option value="WVB">
#      Women's Volleyball
#     </option>
#     <option value="WWP">
#      Women's Water Polo
#     </option>
#    </select>
#    |
#    <select id="acadyr" name="acadyr" onchange="mask('Processing'); changeYears(this.value);">
#     <option value="2021.0">
#      2020-21
#     </option>
#     <option value="2020.0">
#      2019-20
#     </option>
#     <option selected="" value="2019.0">
#      2018-19
#     </option>
#     <option value="2018.0">
#      2017-18
#     </option>
#     <option value="2017.0">
#      2016-17
#     </option>
#     <option value="2016.0">
#      2015-16
#     </option>
#     <option value="2015.0">
#      2014-15
#     </option>
#     <option value="2014.0">
#      2013-14
#     </option>
#     <option value="2013.0">
#      2012-13
#     </option>
#     <option value="2012.0">
#      2011-12
#     </option>
#     <option value="2011.0">
#      2010-11
#     </option>
#     <option value="2010.0">
#      2009-10
#     </option>
#    </select>
#    |
#    <select id="u_div" name="u_div" onchange="mask('Processing'); changeDivisions(this.value);">
#     <option selected="" value="1.0">
#      I
#     </option>
#     <option value="2.0">
#      II
#     </option>
#     <option value="3.0">
#      III
#     </option>
#    </select>
#    |
#    <select id="rp" name="rp" onchange="mask('Processing'); changeRankingPeriod(this.value);">
#     <option selected="" value="83.0">
#      06/05/2019-Final Statistics
#     </option>
#     <option value="52.0">
#      06/05/2019-DI Softball Tournament
#     </option>
#     <option value="77.0">
#      06/05/2019-Women's College World Series
#     </option>
#     <option value="82.0">
#      06/04/2019
#     </option>
#     <option value="81.0">
#      06/03/2019
#     </option>
#     <option value="80.0">
#      06/02/2019
#     </option>
#     <option value="79.0">
#      06/01/2019
#     </option>
#     <option value="78.0">
#      05/31/2019
#     </option>
#     <option value="76.0">
#      05/30/2019
#     </option>
#     <option value="75.0">
#      05/26/2019
#     </option>
#     <option value="74.0">
#      05/25/2019
#     </option>
#     <option value="73.0">
#      05/24/2019
#     </option>
#     <option value="72.0">
#      05/23/2019
#     </option>
#     <option value="71.0">
#      05/20/2019
#     </option>
#     <option value="70.0">
#      05/19/2019
#     </option>
#     <option value="69.0">
#      05/18/2019
#     </option>
#     <option value="68.0">
#      05/16/2019
#     </option>
#     <option value="67.0">
#      05/11/2019
#     </option>
#     <option value="66.0">
#      05/09/2019
#     </option>
#     <option value="65.0">
#      05/08/2019
#     </option>
#     <option value="64.0">
#      05/07/2019
#     </option>
#     <option value="63.0">
#      05/06/2019
#     </option>
#     <option value="62.0">
#      05/05/2019
#     </option>
#     <option value="61.0">
#      05/02/2019
#     </option>
#     <option value="60.0">
#      05/01/2019
#     </option>
#     <option value="59.0">
#      04/30/2019
#     </option>
#     <option value="58.0">
#      04/29/2019
#     </option>
#     <option value="57.0">
#      04/28/2019
#     </option>
#     <option value="56.0">
#      04/25/2019
#     </option>
#     <option value="55.0">
#      04/24/2019
#     </option>
#     <option value="54.0">
#      04/23/2019
#     </option>
#     <option value="53.0">
#      04/22/2019
#     </option>
#     <option value="51.0">
#      04/21/2019
#     </option>
#     <option value="50.0">
#      04/18/2019
#     </option>
#     <option value="49.0">
#      04/17/2019
#     </option>
#     <option value="48.0">
#      04/16/2019
#     </option>
#     <option value="47.0">
#      04/15/2019
#     </option>
#     <option value="46.0">
#      04/14/2019
#     </option>
#     <option value="45.0">
#      04/11/2019
#     </option>
#     <option value="44.0">
#      04/10/2019
#     </option>
#     <option value="43.0">
#      04/09/2019
#     </option>
#     <option value="42.0">
#      04/08/2019
#     </option>
#     <option value="41.0">
#      04/07/2019
#     </option>
#     <option value="40.0">
#      04/04/2019
#     </option>
#     <option value="39.0">
#      04/03/2019
#     </option>
#     <option value="38.0">
#      04/02/2019
#     </option>
#     <option value="37.0">
#      04/01/2019
#     </option>
#     <option value="36.0">
#      03/31/2019
#     </option>
#     <option value="33.0">
#      03/26/2019
#     </option>
#     <option value="31.0">
#      03/24/2019
#     </option>
#     <option value="30.0">
#      03/21/2019
#     </option>
#     <option value="29.0">
#      03/20/2019
#     </option>
#     <option value="28.0">
#      03/19/2019
#     </option>
#     <option value="27.0">
#      03/18/2019
#     </option>
#     <option value="26.0">
#      03/17/2019
#     </option>
#     <option value="25.0">
#      03/14/2019
#     </option>
#     <option value="24.0">
#      03/13/2019
#     </option>
#     <option value="23.0">
#      03/12/2019
#     </option>
#     <option value="22.0">
#      03/11/2019
#     </option>
#     <option value="21.0">
#      03/10/2019
#     </option>
#     <option value="20.0">
#      03/07/2019
#     </option>
#     <option value="19.0">
#      03/06/2019
#     </option>
#     <option value="18.0">
#      03/05/2019
#     </option>
#     <option value="17.0">
#      03/04/2019
#     </option>
#     <option value="16.0">
#      03/03/2019
#     </option>
#     <option value="15.0">
#      02/28/2019
#     </option>
#     <option value="14.0">
#      02/27/2019
#     </option>
#     <option value="13.0">
#      02/26/2019
#     </option>
#     <option value="12.0">
#      02/25/2019
#     </option>
#     <option value="11.0">
#      02/24/2019
#     </option>
#     <option value="10.0">
#      02/21/2019
#     </option>
#     <option value="9.0">
#      02/20/2019
#     </option>
#     <option value="8.0">
#      02/19/2019
#     </option>
#     <option value="7.0">
#      02/18/2019
#     </option>
#     <option value="6.0">
#      02/17/2019
#     </option>
#     <option value="5.0">
#      02/14/2019
#     </option>
#     <option value="4.0">
#      02/13/2019
#     </option>
#     <option value="3.0">
#      02/12/2019
#     </option>
#     <option value="2.0">
#      02/11/2019
#     </option>
#    </select>
#    <br/>
#    <!--
#
# <div id="grey_header_menu">
# <div id="nav_bar">
# <div id="primary_nav_wrap">
# 		<ul class="current-menu-item">
# 		  <li>
# 		    <a href="#" class="skipMask">Softball</a>
# 		    <ul class="level2">
# 		 		    <li><a href="javascript:changeSports('MBA');">Baseball</a></li>
# 		 		    <li><a href="javascript:changeSports('MBB');">Men&#x27;s Basketball</a></li>
# 		 		    <li><a href="javascript:changeSports('MFB');">Football</a></li>
# 		 		    <li><a href="javascript:changeSports('MIH');">Men&#x27;s Ice Hockey</a></li>
# 		 		    <li><a href="javascript:changeSports('MLA');">Men&#x27;s Lacrosse</a></li>
# 		 		    <li><a href="javascript:changeSports('MSO');">Men&#x27;s Soccer</a></li>
# 		 		    <li><a href="javascript:changeSports('MTE');">Men&#x27;s Tennis</a></li>
# 		 		    <li><a href="javascript:changeSports('MVB');">Men&#x27;s Volleyball</a></li>
# 		 		    <li><a href="javascript:changeSports('MWP');">Men&#x27;s Water Polo</a></li>
# 		 		    <li><a href="javascript:changeSports('WBB');">Women&#x27;s Basketball</a></li>
# 		 		    <li><a href="javascript:changeSports('WBW');">Women&#x27;s Bowling</a></li>
# 		 		    <li><a href="javascript:changeSports('WFH');">Field Hockey</a></li>
# 		 		    <li><a href="javascript:changeSports('WIH');">Women&#x27;s Ice Hockey</a></li>
# 		 		    <li><a href="javascript:changeSports('WLA');">Women&#x27;s Lacrosse</a></li>
# 		 		    <li><a href="javascript:changeSports('WSB');">Softball</a></li>
# 		 		    <li><a href="javascript:changeSports('WSO');">Women&#x27;s Soccer</a></li>
# 		 		    <li><a href="javascript:changeSports('WSV');">Women&#x27;s Beach Volleyball</a></li>
# 		 		    <li><a href="javascript:changeSports('WTE');">Women&#x27;s Tennis</a></li>
# 		 		    <li><a href="javascript:changeSports('WVB');">Women&#x27;s Volleyball</a></li>
# 		 		    <li><a href="javascript:changeSports('WWP');">Women&#x27;s Water Polo</a></li>
# 		    </ul>
# 		  </li>
# 		  <li class="sep">|</li>
#  		  <li>
# 			<a href="#">2018-19</a>
# 			<ul class="level2">
# 				<li><a href="javascript:changeYears(2021.0);">2020-21</a></li>
# 				<li><a href="javascript:changeYears(2020.0);">2019-20</a></li>
# 				<li><a href="javascript:changeYears(2019.0);">2018-19</a></li>
# 				<li><a href="javascript:changeYears(2018.0);">2017-18</a></li>
# 				<li><a href="javascript:changeYears(2017.0);">2016-17</a></li>
# 				<li><a href="javascript:changeYears(2016.0);">2015-16</a></li>
# 				<li><a href="javascript:changeYears(2015.0);">2014-15</a></li>
# 				<li><a href="javascript:changeYears(2014.0);">2013-14</a></li>
# 				<li><a href="javascript:changeYears(2013.0);">2012-13</a></li>
# 				<li><a href="javascript:changeYears(2012.0);">2011-12</a></li>
# 				<li><a href="javascript:changeYears(2011.0);">2010-11</a></li>
# 				<li><a href="javascript:changeYears(2010.0);">2009-10</a></li>
# 			</ul>
# 		  </li>
#   	      <li class="sep">|</li>
#  		  <li>
# 			<a href="#" class="skipMask">I</a>
# 			<ul class="level2">
# 				<li><a href="javascript:changeDivisions(1.0);">I</a></li>
# 				<li><a href="javascript:changeDivisions(2.0);">II</a></li>
# 				<li><a href="javascript:changeDivisions(3.0);">III</a></li>
# 			</ul>
# 		  </li>
#   	      <li class="sep">|</li>
#  		  <li>
#           <a href="#" class="skipMask">Thru Games 06/05/2019-Final Statistics</a>
# 			<ul class="level2">
#               <li><a href="javascript:changeRankingPeriod(83.0);">06/05/2019-Final Statistics</a></li>
#               <li><a href="javascript:changeRankingPeriod(52.0);">06/05/2019-DI Softball Tournament</a></li>
#               <li><a href="javascript:changeRankingPeriod(77.0);">06/05/2019-Women&#x27;s College World Series</a></li>
#               <li><a href="javascript:changeRankingPeriod(82.0);">06/04/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(81.0);">06/03/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(80.0);">06/02/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(79.0);">06/01/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(78.0);">05/31/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(76.0);">05/30/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(75.0);">05/26/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(74.0);">05/25/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(73.0);">05/24/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(72.0);">05/23/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(71.0);">05/20/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(70.0);">05/19/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(69.0);">05/18/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(68.0);">05/16/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(67.0);">05/11/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(66.0);">05/09/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(65.0);">05/08/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(64.0);">05/07/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(63.0);">05/06/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(62.0);">05/05/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(61.0);">05/02/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(60.0);">05/01/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(59.0);">04/30/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(58.0);">04/29/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(57.0);">04/28/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(56.0);">04/25/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(55.0);">04/24/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(54.0);">04/23/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(53.0);">04/22/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(51.0);">04/21/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(50.0);">04/18/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(49.0);">04/17/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(48.0);">04/16/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(47.0);">04/15/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(46.0);">04/14/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(45.0);">04/11/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(44.0);">04/10/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(43.0);">04/09/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(42.0);">04/08/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(41.0);">04/07/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(40.0);">04/04/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(39.0);">04/03/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(38.0);">04/02/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(37.0);">04/01/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(36.0);">03/31/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(33.0);">03/26/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(31.0);">03/24/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(30.0);">03/21/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(29.0);">03/20/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(28.0);">03/19/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(27.0);">03/18/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(26.0);">03/17/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(25.0);">03/14/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(24.0);">03/13/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(23.0);">03/12/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(22.0);">03/11/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(21.0);">03/10/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(20.0);">03/07/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(19.0);">03/06/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(18.0);">03/05/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(17.0);">03/04/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(16.0);">03/03/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(15.0);">02/28/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(14.0);">02/27/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(13.0);">02/26/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(12.0);">02/25/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(11.0);">02/24/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(10.0);">02/21/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(9.0);">02/20/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(8.0);">02/19/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(7.0);">02/18/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(6.0);">02/17/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(5.0);">02/14/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(4.0);">02/13/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(3.0);">02/12/2019</a></li>
#               <li><a href="javascript:changeRankingPeriod(2.0);">02/11/2019</a></li>
# 			</ul>
# 		  </li>
#   	 </ul>
# </div>
# </div>
# </div>
# -->
#    <form accept-charset="UTF-8" action="/rankings/national_ranking" data-remote="true" id="national_ranking_form" method="post" onclick="mask('Loading');">
#     <div style="margin:0;padding:0;display:inline">
#      <input name="utf8" type="hidden" value="✓"/>
#      <input name="authenticity_token" type="hidden" value="a3tYSlkLx/1naum2iE6r1AEbslYFbTdQ/XlNeflR1Ow="/>
#     </div>
#     <input id="rankings_academic_year" name="academic_year" type="hidden" value="2019.0"/>
#     <input id="rankings_division" name="division" type="hidden" value="1.0"/>
#     <input id="rankings_ranking_period" name="ranking_period" type="hidden" value="83.0"/>
#     <input id="rankings_sport_code" name="sport_code" type="hidden" value="WSB"/>
#     <input id="rankings_stat_seq" name="stat_seq" type="hidden" value="281"/>
#     <input id="rankings_form_submit_btn" name="submit" style="display:none;" type="submit" value=""/>
#    </form>
#    <form accept-charset="UTF-8" action="/rankings/change_sport_year_div" data-remote="true" id="sports_form_id" method="post" onsubmit="mask('Loading');">
#     <div style="margin:0;padding:0;display:inline">
#      <input name="utf8" type="hidden" value="✓"/>
#      <input name="authenticity_token" type="hidden" value="a3tYSlkLx/1naum2iE6r1AEbslYFbTdQ/XlNeflR1Ow="/>
#     </div>
#     <input id="sports_form_sport_code" name="sport_code" type="hidden" value="WSB"/>
#     <input id="sports_form_academic_year" name="academic_year" type="hidden" value="2019.0"/>
#     <input id="sports_form_division" name="division" type="hidden" value="1.0"/>
#     <input id="sports_form_ranking_period" name="ranking_period" type="hidden" value="83.0"/>
#     <input id="sports_form_team_individual" name="team_individual" type="hidden" value="T"/>
#     <input id="sports_form_game_high" name="game_high" type="hidden" value="N"/>
#     <input id="sports_form_stat_seq" name="stat_seq" type="hidden" value=""/>
#     <input id="sports_form_ranking_summary" name="ranking_summary" type="hidden" value="N"/>
#     <input id="sports_form_org_id" name="org_id" type="hidden" value=""/>
#     <input id="sports_form_conf_id" name="conf_id" type="hidden" value=""/>
#     <input id="sports_form_region_id" name="region_id" type="hidden" value=""/>
#     <input id="sports_form_ncaa_custom_rank_summary_id" name="ncaa_custom_rank_summary_id" type="hidden" value=""/>
#     <input id="sports_form_user_custom_rank_summary_id" name="user_custom_rank_summary_id" type="hidden" value=""/>
#     <input name="render_partial" type="hidden" value="Y"/>
#     <input id="sports_form_submit_btn" name="submit" style="display:none;" type="submit" value=""/>
#    </form>
#    <form action="/rankings" method="post" name="ranking_form" target="RANKINGS_WINDOW">
#     <input id="ranking_form_sport_code" name="sport_code" type="hidden" value="WSB"/>
#     <input id="ranking_form_academic_year" name="academic_year" type="hidden" value="2019.0"/>
#     <input id="ranking_form_division" name="division" type="hidden" value="1.0"/>
#     <input id="ranking_form_ranking_period" name="ranking_period" type="hidden" value="83.0"/>
#     <input id="ranking_form_team_individual" name="team_individual" type="hidden" value="T"/>
#     <input id="ranking_form_game_high" name="game_high" type="hidden" value="N"/>
#     <input id="ranking_form_stat_seq" name="stat_seq" type="hidden" value=""/>
#     <input id="authenticity_token" name="authenticity_token" type="hidden" value="a3tYSlkLx/1naum2iE6r1AEbslYFbTdQ/XlNeflR1Ow="/>
#    </form>
#    <form action="/rankings/change_sport_year_div" method="post" name="sport_year_div_form">
#     <input id="sport_year_div_sport_code" name="sport_code" type="hidden" value="WSB"/>
#     <input id="sport_year_div_academic_year" name="academic_year" type="hidden" value="2019.0"/>
#     <input id="sport_year_div_division" name="division" type="hidden" value="1.0"/>
#     <input id="sport_year_div_ranking_period" name="ranking_period" type="hidden" value="83.0"/>
#     <input id="sport_year_div_team_individual" name="team_individual" type="hidden" value="T"/>
#     <input id="sport_year_div_game_high" name="game_high" type="hidden" value="N"/>
#     <input id="sport_year_div_ranking_summary" name="ranking_summary" type="hidden" value="N"/>
#     <input id="sport_year_div_org_id" name="org_id" type="hidden" value="-1"/>
#     <input id="sport_year_div_stat_seq" name="stat_seq" type="hidden" value="350"/>
#     <input id="sport_year_div_conf_id" name="conf_id" type="hidden" value="-1"/>
#     <input id="sport_year_div_region_id" name="region_id" type="hidden" value="-1"/>
#     <input id="sport_year_div_ncaa_custom_rank_summary_id" name="ncaa_custom_rank_summary_id" type="hidden" value="-1"/>
#     <input id="sport_year_div_user_custom_rank_summary_id" name="user_custom_rank_summary_id" type="hidden" value="-1"/>
#     <input id="authenticity_token" name="authenticity_token" type="hidden" value="a3tYSlkLx/1naum2iE6r1AEbslYFbTdQ/XlNeflR1Ow="/>
#    </form>
#    <!-- tabs -->
#    <ul class="css-tabs">
#     <li>
#      <a href="javascript:changeStatType('I', 'N');" id="stat_type_I_N">
#       Individual
#      </a>
#     </li>
#     <li>
#      <a href="javascript:changeStatType('I', 'Y');" id="stat_type_I_Y">
#       Individual Game Highs
#      </a>
#     </li>
#     <li>
#      <a class="current" href="javascript:changeStatType('T', 'N');" id="stat_type_T_N">
#       Team
#      </a>
#     </li>
#     <li>
#      <a href="javascript:changeStatType('T', 'Y');" id="stat_type_T_Y">
#       Team Game Highs
#      </a>
#     </li>
#     <li>
#      <a href="javascript:changeRankingSummaryTab();" id="ranking_summary">
#       Ranking Summary
#      </a>
#     </li>
#     <li>
#      <a href="javascript:submitSportYearDivForm('conference_trends');" id="trends">
#       Trends
#      </a>
#     </li>
#     <li>
#      <a data-remote="true" href="/reports/index?division=1.0&amp;id=14800" id="misc_reports">
#       Misc Reports
#      </a>
#     </li>
#    </ul>
#    <!-- single pane. it is always visible -->
#    <!--
# <div class="css-panes">
#   -->
#    <div class="rankings_pane" id="national_ranking_div">
#     <script charset="utf-8" type="text/javascript">
#      var lengthMenuA = [];
#     var lengthMenuB = [];
#                 lengthMenuA.push("10");
#                 lengthMenuB.push("10");
#                 lengthMenuA.push("25");
#                 lengthMenuB.push("25");
#                 lengthMenuA.push("50");
#                 lengthMenuB.push("50");
#                 lengthMenuA.push("-1");
#                 lengthMenuB.push("295");
# function initDataTable(){
#           var oTable = $('#rankings_table').DataTable({
#             dom: 'R<"clear">lfrtip',
#             bStateSave: true,
#             iCookieDuration : 60*60*24*1000,
#             sPaginationType: "full_numbers",
#             language: {
#               emptyTable:  "No teams ranked"
#             },
#             order: [[0, "asc"]],
#             pageLength: 50,
#             lengthMenu: [lengthMenuA, lengthMenuB],
#             columnDefs: [
#             {
#               targets: [0],
#               orderData: [0,0]
#             },
#             {
#               targets: [1],
#               orderData: [1,0]
#             },
#             {
#               targets: [2],
#               orderData: [2,0]
#             },
#             {
#               targets: [3],
#               orderData: [3,0]
#             },
#             {
#               targets: [4],
#               orderData: [4,0]
#             }
#             ]
#           } );
# }
#     </script>
#     <form accept-charset="UTF-8" action="/rankings/national_ranking" data-remote="true" id="change_stat_form" method="post" onsubmit="mask('Loading');">
#      <div style="margin:0;padding:0;display:inline">
#       <input name="utf8" type="hidden" value="✓"/>
#       <input name="authenticity_token" type="hidden" value="P2zYb28FOgJCGMpIQNpGJKnGyWFJK2t26RtvSM8uT3o="/>
#      </div>
#      <input name="sport_code" type="hidden" value="WSB"/>
#      <input id="change_stat_form_stat_seq" name="stat_seq" type="hidden" value=""/>
#      <input name="academic_year" type="hidden" value="2019.0"/>
#      <input name="division" type="hidden" value="1.0"/>
#      <input name="ranking_period" type="hidden" value="83.0"/>
#      <input id="change_stat_form_submit_btn" name="submit" style="display:none;" type="submit"/>
#     </form>
#     <table width="100%">
#      <tbody>
#       <tr>
#        <td align="left">
#         <select id="stat_seq" name="stat_seq" onchange="$('#change_stat_form_stat_seq').val(this.value); $('#change_stat_form_submit_btn').click();">
#          <option value="281">
#           Batting Average
#          </option>
#          <option selected="selected" value="350">
#           Double Plays per Game
#          </option>
#          <option value="346">
#           Doubles per Game
#          </option>
#          <option value="282">
#           Earned Run Average
#          </option>
#          <option value="283">
#           Fielding Percentage
#          </option>
#          <option value="595">
#           Hit Batters
#          </option>
#          <option value="345">
#           Home Runs per game
#          </option>
#          <option value="862">
#           On Base Percentage
#          </option>
#          <option value="284">
#           Scoring
#          </option>
#          <option value="1084">
#           Shutouts
#          </option>
#          <option value="349">
#           Slugging Percentage
#          </option>
#          <option value="348">
#           Stolen Bases per Game
#          </option>
#          <option value="1188">
#           Strikeout-to-Walk Ratio
#          </option>
#          <option value="347">
#           Triples per Game
#          </option>
#          <option value="320">
#           WL Percentage
#          </option>
#         </select>
#         <a class="skipMask" href="#" onclick="showLegacyPDF(83, 350, 1, 'WSB', 2019); return false;">
#          <img alt="Page_white_acrobat" src="/assets/page_white_acrobat-3fc4cfab39df5d80ac7aae3b6a479f2f.png"/>
#         </a>
#        </td>
#        <td>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#     <div class="dataTables_wrapper" id="rankings_table_wrapper">
#      <div class="clear">
#      </div>
#      <div class="dataTables_length" id="rankings_table_length">
#       <label>
#        Show
#        <select aria-controls="rankings_table" class="" name="rankings_table_length">
#         <option value="10">
#          10
#         </option>
#         <option value="25">
#          25
#         </option>
#         <option value="50">
#          50
#         </option>
#         <option value="-1">
#          295
#         </option>
#        </select>
#        entries
#       </label>
#      </div>
#      <div class="dataTables_filter" id="rankings_table_filter">
#       <label>
#        Search:
#        <input aria-controls="rankings_table" class="" placeholder="" type="search"/>
#       </label>
#      </div>
#      <table aria-describedby="rankings_table_info" class="mytbl dataTable" id="rankings_table" role="grid" style="width: 100%;" width="100%">
#       <thead>
#        <tr class="splash_col_heading" role="row">
#         <th align="left" aria-controls="rankings_table" aria-label="Rank: activate to sort column descending" aria-sort="ascending" class="sorting_asc" colspan="1" data-column-index="0" rowspan="1" style="width: 33px;" tabindex="0" width="5%">
#          Rank
#         </th>
#         <th align="left" aria-controls="rankings_table" aria-label="Team: activate to sort column ascending" class="sorting" colspan="1" data-column-index="1" rowspan="1" style="width: 551px;" tabindex="0">
#          Team
#         </th>
#         <th align='"right"' aria-controls="rankings_table" aria-label="G: activate to sort column ascending" class="sorting" colspan="1" data-column-index="2" nowrap="" rowspan="1" style="width: 96px;" tabindex="0" width='"5%"'>
#          G
#         </th>
#         <th align='"right"' aria-controls="rankings_table" aria-label="DP: activate to sort column ascending" class="sorting" colspan="1" data-column-index="3" nowrap="" rowspan="1" style="width: 116px;" tabindex="0" width='"5%"'>
#          DP
#         </th>
#         <th align='"right"' aria-controls="rankings_table" aria-label="PG: activate to sort column ascending" class="sorting" colspan="1" data-column-index="4" nowrap="" rowspan="1" style="width: 122px;" tabindex="0" width='"5%"'>
#          PG
#         </th>
#        </tr>
#       </thead>
#       <tbody>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="1">
#          1
#         </td>
#         <td class="reclass" data-order="Hofstra,CAA">
#          <a class="skipMask" href="/team/283.0/14800" target="TEAM_WIN">
#           Hofstra (CAA)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          47
#         </td>
#         <td align="right" nowrap="">
#          33
#         </td>
#         <td align="right" nowrap="">
#          0.70
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="2">
#          1
#         </td>
#         <td class="reclass" data-order="CSU Bakersfield,WAC">
#          <a class="skipMask" href="/team/94.0/14800" target="TEAM_WIN">
#           CSU Bakersfield (WAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          47
#         </td>
#         <td align="right" nowrap="">
#          33
#         </td>
#         <td align="right" nowrap="">
#          0.70
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="3">
#          3
#         </td>
#         <td class="reclass" data-order="Fla. Atlantic,C-USA">
#          <a class="skipMask" href="/team/229.0/14800" target="TEAM_WIN">
#           Fla. Atlantic (C-USA)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          50
#         </td>
#         <td align="right" nowrap="">
#          31
#         </td>
#         <td align="right" nowrap="">
#          0.62
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="4">
#          4
#         </td>
#         <td class="reclass" data-order="Oklahoma St.,Big 12">
#          <a class="skipMask" href="/team/521.0/14800" target="TEAM_WIN">
#           Oklahoma St. (Big 12)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          62
#         </td>
#         <td align="right" nowrap="">
#          38
#         </td>
#         <td align="right" nowrap="">
#          0.61
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="5">
#          5
#         </td>
#         <td class="reclass" data-order="Utah Valley,WAC">
#          <a class="skipMask" href="/team/30024.0/14800" target="TEAM_WIN">
#           Utah Valley (WAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          46
#         </td>
#         <td align="right" nowrap="">
#          27
#         </td>
#         <td align="right" nowrap="">
#          0.59
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="6">
#          6
#         </td>
#         <td class="reclass" data-order="Wisconsin,Big Ten">
#          <a class="skipMask" href="/team/796.0/14800" target="TEAM_WIN">
#           Wisconsin (Big Ten)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          57
#         </td>
#         <td align="right" nowrap="">
#          33
#         </td>
#         <td align="right" nowrap="">
#          0.58
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="7">
#          7
#         </td>
#         <td class="reclass" data-order="Ohio St.,Big Ten">
#          <a class="skipMask" href="/team/518.0/14800" target="TEAM_WIN">
#           Ohio St. (Big Ten)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          53
#         </td>
#         <td align="right" nowrap="">
#          29
#         </td>
#         <td align="right" nowrap="">
#          0.55
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="8">
#          8
#         </td>
#         <td class="reclass" data-order="A&amp;M-Corpus Christi,Southland">
#          <a class="skipMask" href="/team/26172.0/14800" target="TEAM_WIN">
#           A&amp;M-Corpus Christi (Southland)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          51
#         </td>
#         <td align="right" nowrap="">
#          27
#         </td>
#         <td align="right" nowrap="">
#          0.53
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="9">
#          9
#         </td>
#         <td class="reclass" data-order="Grand Canyon,WAC">
#          <a class="skipMask" href="/team/1104.0/14800" target="TEAM_WIN">
#           Grand Canyon (WAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          57
#         </td>
#         <td align="right" nowrap="">
#          30
#         </td>
#         <td align="right" nowrap="">
#          0.53
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="10">
#          10
#         </td>
#         <td class="reclass" data-order="Abilene Christian,Southland">
#          <a class="skipMask" href="/team/2.0/14800" target="TEAM_WIN">
#           Abilene Christian (Southland)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          44
#         </td>
#         <td align="right" nowrap="">
#          23
#         </td>
#         <td align="right" nowrap="">
#          0.52
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="11">
#          11
#         </td>
#         <td class="reclass" data-order="UNLV,MWC">
#          <a class="skipMask" href="/team/465.0/14800" target="TEAM_WIN">
#           UNLV (MWC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          50
#         </td>
#         <td align="right" nowrap="">
#          26
#         </td>
#         <td align="right" nowrap="">
#          0.52
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="12">
#          11
#         </td>
#         <td class="reclass" data-order="UAB,C-USA">
#          <a class="skipMask" href="/team/9.0/14800" target="TEAM_WIN">
#           UAB (C-USA)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          50
#         </td>
#         <td align="right" nowrap="">
#          26
#         </td>
#         <td align="right" nowrap="">
#          0.52
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="13">
#          13
#         </td>
#         <td class="reclass" data-order="Utah,Pac-12">
#          <a class="skipMask" href="/team/732.0/14800" target="TEAM_WIN">
#           Utah (Pac-12)
# ...
#          <a class="skipMask" href="/team/391.0/14800" target="TEAM_WIN">
#           UMBC (America East)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          54
#         </td>
#         <td align="right" nowrap="">
#          8
#         </td>
#         <td align="right" nowrap="">
#          0.15
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="274">
#          274
#         </td>
#         <td class="reclass" data-order="Princeton,Ivy League">
#          <a class="skipMask" href="/team/554.0/14800" target="TEAM_WIN">
#           Princeton (Ivy League)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          41
#         </td>
#         <td align="right" nowrap="">
#          6
#         </td>
#         <td align="right" nowrap="">
#          0.15
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="275">
#          275
#         </td>
#         <td class="reclass" data-order="Ohio,MAC">
#          <a class="skipMask" href="/team/519.0/14800" target="TEAM_WIN">
#           Ohio (MAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          55
#         </td>
#         <td align="right" nowrap="">
#          8
#         </td>
#         <td align="right" nowrap="">
#          0.15
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="276">
#          276
#         </td>
#         <td class="reclass" data-order="Saint Peter's,MAAC">
#          <a class="skipMask" href="/team/617.0/14800" target="TEAM_WIN">
#           Saint Peter's (MAAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          56
#         </td>
#         <td align="right" nowrap="">
#          8
#         </td>
#         <td align="right" nowrap="">
#          0.14
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="277">
#          276
#         </td>
#         <td class="reclass" data-order="Penn St.,Big Ten">
#          <a class="skipMask" href="/team/539.0/14800" target="TEAM_WIN">
#           Penn St. (Big Ten)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          56
#         </td>
#         <td align="right" nowrap="">
#          8
#         </td>
#         <td align="right" nowrap="">
#          0.14
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="278">
#          278
#         </td>
#         <td class="reclass" data-order="Indiana,Big Ten">
#          <a class="skipMask" href="/team/306.0/14800" target="TEAM_WIN">
#           Indiana (Big Ten)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          57
#         </td>
#         <td align="right" nowrap="">
#          8
#         </td>
#         <td align="right" nowrap="">
#          0.14
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="279">
#          279
#         </td>
#         <td class="reclass" data-order="SIUE,OVC">
#          <a class="skipMask" href="/team/660.0/14800" target="TEAM_WIN">
#           SIUE (OVC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          44
#         </td>
#         <td align="right" nowrap="">
#          6
#         </td>
#         <td align="right" nowrap="">
#          0.14
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="280">
#          280
#         </td>
#         <td class="reclass" data-order="Drake,MVC">
#          <a class="skipMask" href="/team/189.0/14800" target="TEAM_WIN">
#           Drake (MVC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          59
#         </td>
#         <td align="right" nowrap="">
#          8
#         </td>
#         <td align="right" nowrap="">
#          0.14
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="281">
#          281
#         </td>
#         <td class="reclass" data-order="Southern U.,SWAC">
#          <a class="skipMask" href="/team/665.0/14800" target="TEAM_WIN">
#           Southern U. (SWAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          35
#         </td>
#         <td align="right" nowrap="">
#          4
#         </td>
#         <td align="right" nowrap="">
#          0.11
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="282">
#          282
#         </td>
#         <td class="reclass" data-order="New Mexico,MWC">
#          <a class="skipMask" href="/team/473.0/14800" target="TEAM_WIN">
#           New Mexico (MWC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          53
#         </td>
#         <td align="right" nowrap="">
#          6
#         </td>
#         <td align="right" nowrap="">
#          0.11
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="283">
#          283
#         </td>
#         <td class="reclass" data-order="Morehead St.,OVC">
#          <a class="skipMask" href="/team/444.0/14800" target="TEAM_WIN">
#           Morehead St. (OVC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          45
#         </td>
#         <td align="right" nowrap="">
#          5
#         </td>
#         <td align="right" nowrap="">
#          0.11
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="284">
#          284
#         </td>
#         <td class="reclass" data-order="Arkansas,SEC">
#          <a class="skipMask" href="/team/31.0/14800" target="TEAM_WIN">
#           Arkansas (SEC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          58
#         </td>
#         <td align="right" nowrap="">
#          6
#         </td>
#         <td align="right" nowrap="">
#          0.10
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="285">
#          285
#         </td>
#         <td class="reclass" data-order="Western Ky.,C-USA">
#          <a class="skipMask" href="/team/772.0/14800" target="TEAM_WIN">
#           Western Ky. (C-USA)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          50
#         </td>
#         <td align="right" nowrap="">
#          5
#         </td>
#         <td align="right" nowrap="">
#          0.10
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="286">
#          286
#         </td>
#         <td class="reclass" data-order="Texas Southern,SWAC">
#          <a class="skipMask" href="/team/699.0/14800" target="TEAM_WIN">
#           Texas Southern (SWAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          52
#         </td>
#         <td align="right" nowrap="">
#          5
#         </td>
#         <td align="right" nowrap="">
#          0.10
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="287">
#          287
#         </td>
#         <td class="reclass" data-order="Bryant,NEC">
#          <a class="skipMask" href="/team/81.0/14800" target="TEAM_WIN">
#           Bryant (NEC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          45
#         </td>
#         <td align="right" nowrap="">
#          4
#         </td>
#         <td align="right" nowrap="">
#          0.09
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="288">
#          288
#         </td>
#         <td class="reclass" data-order="North Dakota St.,Summit League">
#          <a class="skipMask" href="/team/493.0/14800" target="TEAM_WIN">
#           North Dakota St. (Summit League)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          58
#         </td>
#         <td align="right" nowrap="">
#          5
#         </td>
#         <td align="right" nowrap="">
#          0.09
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="289">
#          289
#         </td>
#         <td class="reclass" data-order="SFA,Southland">
#          <a class="skipMask" href="/team/676.0/14800" target="TEAM_WIN">
#           SFA (Southland)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          59
#         </td>
#         <td align="right" nowrap="">
#          5
#         </td>
#         <td align="right" nowrap="">
#          0.08
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="290">
#          290
#         </td>
#         <td class="reclass" data-order="UIW,Southland">
#          <a class="skipMask" href="/team/2743.0/14800" target="TEAM_WIN">
#           UIW (Southland)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          48
#         </td>
#         <td align="right" nowrap="">
#          4
#         </td>
#         <td align="right" nowrap="">
#          0.08
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="291">
#          290
#         </td>
#         <td class="reclass" data-order="Savannah St.,MEAC">
#          <a class="skipMask" href="/team/632.0/14800" target="TEAM_WIN">
#           Savannah St. (MEAC)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          36
#         </td>
#         <td align="right" nowrap="">
#          3
#         </td>
#         <td align="right" nowrap="">
#          0.08
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="292">
#          292
#         </td>
#         <td class="reclass" data-order="Holy Cross,Patriot">
#          <a class="skipMask" href="/team/285.0/14800" target="TEAM_WIN">
#           Holy Cross (Patriot)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          49
#         </td>
#         <td align="right" nowrap="">
#          4
#         </td>
#         <td align="right" nowrap="">
#          0.08
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="293">
#          292
#         </td>
#         <td class="reclass" data-order="Georgetown,Big East">
#          <a class="skipMask" href="/team/251.0/14800" target="TEAM_WIN">
#           Georgetown (Big East)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          49
#         </td>
#         <td align="right" nowrap="">
#          4
#         </td>
#         <td align="right" nowrap="">
#          0.08
#         </td>
#        </tr>
#        <tr class="row_even even" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="294">
#          294
#         </td>
#         <td class="reclass" data-order="Dayton,Atlantic 10">
#          <a class="skipMask" href="/team/175.0/14800" target="TEAM_WIN">
#           Dayton (Atlantic 10)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          51
#         </td>
#         <td align="right" nowrap="">
#          4
#         </td>
#         <td align="right" nowrap="">
#          0.08
#         </td>
#        </tr>
#        <tr class="row_odd odd" role="row">
#         <td class="reclass sorting_1 sorting_2" data-order="295">
#          295
#         </td>
#         <td class="reclass" data-order="Western Ill.,Summit League">
#          <a class="skipMask" href="/team/771.0/14800" target="TEAM_WIN">
#           Western Ill. (Summit League)
#          </a>
#         </td>
#         <td align="right" nowrap="">
#          40
#         </td>
#         <td align="right" nowrap="">
#          3
#         </td>
#         <td align="right" nowrap="">
#          0.08
#         </td>
#        </tr>
#       </tbody>
#       <tfoot>
#        <tr>
#         <td align="center" colspan="5" rowspan="1">
#          Reclassifying
#         </td>
#        </tr>
#        <tr class="row_odd">
#         <td class="reclass" colspan="1" data-order="1" rowspan="1">
#          -
#         </td>
#         <td class="reclass" colspan="1" data-order="California Baptist,WAC" rowspan="1">
#          California Baptist (WAC)
#         </td>
#         <td align="right" class="reclass" colspan="1" nowrap="" rowspan="1">
#          54
#         </td>
#         <td align="right" class="reclass" colspan="1" nowrap="" rowspan="1">
#          13
#         </td>
#         <td align="right" class="reclass" colspan="1" nowrap="" rowspan="1">
#          0.24
#         </td>
#        </tr>
#        <tr class="row_even">
#         <td class="reclass" colspan="1" data-order="2" rowspan="1">
#          -
#         </td>
#         <td class="reclass" colspan="1" data-order="North Ala.,ASUN" rowspan="1">
#          North Ala. (ASUN)
#         </td>
#         <td align="right" class="reclass" colspan="1" nowrap="" rowspan="1">
#          46
#         </td>
#         <td align="right" class="reclass" colspan="1" nowrap="" rowspan="1">
#          9
#         </td>
#         <td align="right" class="reclass" colspan="1" nowrap="" rowspan="1">
#          0.20
#         </td>
#        </tr>
#       </tfoot>
#      </table>
#      <div aria-live="polite" class="dataTables_info" id="rankings_table_info" role="status">
#       Showing 1 to 295 of 295 entries
#      </div>
#      <div class="dataTables_paginate paging_full_numbers" id="rankings_table_paginate">
#       <a aria-controls="rankings_table" class="paginate_button first disabled" data-dt-idx="0" id="rankings_table_first" tabindex="0">
#        First
#       </a>
#       <a aria-controls="rankings_table" class="paginate_button previous disabled" data-dt-idx="1" id="rankings_table_previous" tabindex="0">
#        Previous
#       </a>
#       <span>
#        <a aria-controls="rankings_table" class="paginate_button current" data-dt-idx="2" tabindex="0">
#         1
#        </a>
#       </span>
#       <a aria-controls="rankings_table" class="paginate_button next disabled" data-dt-idx="3" id="rankings_table_next" tabindex="0">
#        Next
#       </a>
#       <a aria-controls="rankings_table" class="paginate_button last disabled" data-dt-idx="4" id="rankings_table_last" tabindex="0">
#        Last
#       </a>
#      </div>
#     </div>
#     <script>
#      init_tabs("#stat_type_T_N");
#     initRankingsCall(350.0, -1, -1, -1, -1, -1);
#     $(document).ready(initDataTable());
#     </script>
#    </div>
#    <!--
# </div>
# -->
#    <!-- activate tabs with JavaScript -->
#    <script>
#     init_tabs("#stat_type_T_N");
#
#
# $(function() {
#
# 	$("ul.css-tabs").tabs("div.national_ranking_div > div", {effect: 'ajax'});
#
# });
#    </script>
#    <br/>
#   </div>
#   <div class="footer">
#   </div>
#   <script>
#    //ui-datepicker = calendar month prev/next buttons,
#       //ui-corner-all = autocomplete dropdown results
#       //paginate_button = datatables
#     function skipMask(obj){
#       if (obj.hasClass('chosen-single') || obj.hasClass('skipMask') || obj.hasClass('ui-datepicker-prev') || obj.hasClass('ui-datepicker-next') || obj.hasClass('ui-corner-all') || obj.hasClass('paginate_button') || obj.hasClass('dt-button')){
#         return true;
#       }else{
#         return false;
#       }
#     }
#
#     $(document).ajaxComplete(function(){
#       unmask();
#     });
# /*
#     $("form").on('submit', function(event){
#       if (skipMask($(this))){
#         return;
#       }else{
#         mask('Loading');
#       }
#     });
#     */
#     $(document).on('click', 'a', function(){
#       if (skipMask($(this))){
#         return;
#       }else{
#         mask('Loading');
#       }
#     });
#     $(document).on('click', 'input.green', function(){
#       if (skipMask($(this))){
#         return;
#       }else{
#         mask('Loading');
#       }
#     });
#   </script>
#   <ul class="ui-autocomplete ui-front ui-menu ui-widget ui-widget-content ui-corner-all" id="ui-id-1" style="display: none;" tabindex="0">
#   </ul>
#  </body>
# </html>

# %%
table1 = soup_level1.find("table", attrs={"id": "rankings_table"})
table_data1 = table1.tbody.find_all("tr") 

# get heading separately --> thead
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-9f14a91dff96> in <module>
#       5 for td in table_data1[0].find_all("td"):
#       6     # remove any newlines and extra spaces from left and right
# ----> 7     headings1.append(td.b.text.replace('\n', ' ').strip())
#       8
#       9 print(headings1)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
table_data1[0].find_all("td")
# Out:
# [<td class="reclass sorting_1 sorting_2" data-order="1">1</td>,
#  <td class="reclass" data-order="Hofstra,CAA"><a class="skipMask" href="/team/283.0/14800" target="TEAM_WIN">Hofstra (CAA)</a></td>,
#  <td align="right" nowrap="">
#              47
#            </td>,
#  <td align="right" nowrap="">
#              33
#            </td>,
#  <td align="right" nowrap="">
#              0.70
#            </td>]

# %%
driver.close()
